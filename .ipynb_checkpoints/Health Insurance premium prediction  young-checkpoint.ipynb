# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as  plt
import seaborn as sns
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error,mean_squared_error
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV,RandomizedSearchCV

# %%
df=pd.read_excel(r"C:\Users\ankit\Python Project\Helth insurance project\premiums_young.xlsx")

# %%
df.head(2)
# Out:
#    Unnamed: 0  Age  Gender     Region Marital_status  Number Of Dependants  \
# 0           4   18    Male  Northeast      Unmarried                     0
# 1           9   22  Female  Northwest      Unmarried                     0
#
#   BMI_Category Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0   Overweight        Regular     Self-Employed        > 40L            99
# 1  Underweight     No Smoking        Freelancer         <10L             3
#
#        Medical History Insurance_Plan  Annual_Premium_Amount
# 0  High blood pressure         Silver                  13365
# 1           No Disease         Silver                  11050

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Gender', 'Region', 'Marital_status',
#        'Number Of Dependants', 'BMI_Category', 'Smoking_Status',
#        'Employment_Status', 'Income_Level', 'Income_Lakhs', 'Medical History',
#        'Insurance_Plan', 'Annual_Premium_Amount'],
#       dtype='object')

# %%
df.shape
# Out:
# (17563, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17563 entries, 0 to 17562
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             17563 non-null  int64
#  1   Age                    17563 non-null  int64
#  2   Gender                 17563 non-null  object
#  3   Region                 17563 non-null  object
#  4   Marital_status         17563 non-null  object
#  5   Number Of Dependants   17563 non-null  int64
#  6   BMI_Category           17563 non-null  object
#  7   Smoking_Status         17561 non-null  object
#  8   Employment_Status      17562 non-null  object
#  9   Income_Level           17559 non-null  object
#  10  Income_Lakhs           17563 non-null  int64
#  11  Medical History        17563 non-null  object
#  12  Insurance_Plan         17563 non-null  object
#  13  Annual_Premium_Amount  17563 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0           Age  Number Of Dependants  Income_Lakhs  \
# count  17563.000000  17563.000000          17563.000000  17563.000000
# mean   24934.911519     20.988385              0.715823     22.648579
# std    14437.946086      1.998286              0.938451     23.775222
# min        4.000000     18.000000             -3.000000      1.000000
# 25%    12281.000000     19.000000              0.000000      6.000000
# 50%    24869.000000     21.000000              0.000000     16.000000
# 75%    37371.500000     23.000000              1.000000     31.000000
# max    49998.000000     24.000000              3.000000    790.000000
#
#        Annual_Premium_Amount
# count           17563.000000
# mean             8161.698856
# std              2763.912827
# min              3501.000000
# 25%              6035.000000
# 50%              7951.000000
# 75%              9574.000000
# max             18186.000000

# %%
df.columns=df.columns.str.replace(" ","_").str.lower()

# %%
df.columns
# Out:
# Index(['unnamed:_0', 'age', 'gender', 'region', 'marital_status',
#        'number_of_dependants', 'bmi_category', 'smoking_status',
#        'employment_status', 'income_level', 'income_lakhs', 'medical_history',
#        'insurance_plan', 'annual_premium_amount'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# unnamed:_0               0
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           2
# employment_status        1
# income_level             4
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# dtype: int64

# %% [markdown]
# ## Handling nulls and duplicates

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#          unnamed:_0           age  number_of_dependants  income_lakhs  \
# count  17557.000000  17557.000000          17557.000000  17557.000000
# mean   24936.724725     20.988609              0.715840     22.653585
# std    14438.718934      1.998258              0.938388     23.777397
# min        4.000000     18.000000             -3.000000      1.000000
# 25%    12279.000000     19.000000              0.000000      6.000000
# 50%    24873.000000     21.000000              0.000000     16.000000
# 75%    37374.000000     23.000000              1.000000     31.000000
# max    49998.000000     24.000000              3.000000    790.000000
#
#        annual_premium_amount
# count           17557.000000
# mean             8161.883237
# std              2764.254265
# min              3501.000000
# 25%              6035.000000
# 50%              7951.000000
# 75%              9575.000000
# max             18186.000000

# %%
df[df.number_of_dependants<0]["number_of_dependants"].value_counts()
# Out:
# number_of_dependants
# -3    11
# -1     6
# Name: count, dtype: int64

# %%
df.number_of_dependants=np.abs(df.number_of_dependants)

# %%
df.number_of_dependants.describe()
# Out:
# count    17557.000000
# mean         0.720283
# std          0.934982
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          3.000000
# Name: number_of_dependants, dtype: float64

# %% [markdown]
# # Outlier Treatment

# %%
def bplot(data):

    q1=data.quantile(0.25)
    q3=data.quantile(0.75)
    IQR=q3-q1
    lower=q1-1.5*IQR
    upper=q3+1.5*IQR

    
    sns.boxplot(data)
    plt.axhline(lower, color='red', linestyle='--', label='Lower Bound')
    plt.axhline(upper, color='blue', linestyle='--', label='Upper Bound')
    plt.legend()
    plt.show()

# %%
for c in df.select_dtypes([float,int]).columns:
    bplot(df[c])

# %%
df1=df[df.age<=100].copy()

# %% [markdown]
# # univariate analysis

# %%
sns.histplot(df1.income_lakhs,kde=True)
# Out:
# <Axes: xlabel='income_lakhs', ylabel='Count'>

# %%
def iqr_bounds(data):
    q1=data.quantile(0.25)
    q3=data.quantile(0.75)
    IQR=q3-q1
    lower=q1-1.5*IQR
    upper=q3+1.5*IQR
    return upper,lower

# %%
df2=df1[df1.income_lakhs<=df1.income_lakhs.quantile(0.999)].copy()

# %%
df2.describe()
# Out:
#          unnamed:_0           age  number_of_dependants  income_lakhs  \
# count  17553.000000  17553.000000          17553.000000  17553.000000
# mean   24940.028713     20.988606              0.720447     22.515752
# std    14438.577143      1.998457              0.935025     21.867015
# min        4.000000     18.000000              0.000000      1.000000
# 25%    12288.000000     19.000000              0.000000      6.000000
# 50%    24877.000000     21.000000              0.000000     16.000000
# 75%    37375.000000     23.000000              1.000000     31.000000
# max    49998.000000     24.000000              3.000000    100.000000
#
#        annual_premium_amount
# count           17553.000000
# mean             8161.547884
# std              2764.266929
# min              3501.000000
# 25%              6035.000000
# 50%              7951.000000
# 75%              9574.000000
# max             18186.000000

# %%
fig,axes=plt.subplots(2,2,figsize=(18,18))
axes=axes.flatten()



for ax,col in zip(axes,df2.select_dtypes([float,int]).columns):
    
    
    plt.title(f"Histogam of {col}")
    sns.histplot(df2[col],kde=True,ax=ax)
    
plt.tight_layout()    
plt.show()

# %% [markdown]
# # Bivariate analysis

# %%
for col in df2.select_dtypes([float,int]).columns:
    if col=="annual_premium_amount":
        continue
    sns.scatterplot(x=df2[col],y=df2.annual_premium_amount)
    plt.show()

# %%
for col in df2.select_dtypes('object').columns:
    print(f"{col}:",df2[col].unique())
# Out:
# gender: ['Male' 'Female']
# region: ['Northeast' 'Northwest' 'Southeast' 'Southwest']
# marital_status: ['Unmarried' 'Married']
# bmi_category: ['Overweight' 'Underweight' 'Normal' 'Obesity']
# smoking_status: ['Regular' 'No Smoking' 'Occasional' 'Not Smoking' 'Does Not Smoke'
#  'Smoking=0']
# employment_status: ['Self-Employed' 'Freelancer' 'Salaried']
# income_level: ['> 40L' '<10L' '10L - 25L' '25L - 40L']
# medical_history: ['High blood pressure' 'No Disease' 'Diabetes & High blood pressure'
#  'Diabetes & Heart disease' 'Diabetes' 'Diabetes & Thyroid'
#  'Heart disease' 'Thyroid' 'High blood pressure & Heart disease']
# insurance_plan: ['Silver' 'Bronze' 'Gold']

# %%
df2["smoking_status"]=df2["smoking_status"].replace({'Smoking=0':'No Smoking',
                                   'Does Not Smoke':'No Smoking',
                                   'Not Smoking':'No Smoking'}
                                   )

# %%
pct_count=df2["gender"].value_counts(normalize=True)

# %%
sns.barplot(x=pct_count.index,y=pct_count.values)
plt.show()

# %%
len(df2.select_dtypes('object').columns)
# Out:
# 9

# %%
categorical_column=df2.select_dtypes(object).columns
categorical_column
# Out:
# Index(['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status',
#        'employment_status', 'income_level', 'medical_history',
#        'insurance_plan'],
#       dtype='object')

# %%
fig,axes=plt.subplots(3,3,figsize=(18,18))
axes=axes.flatten()

for ax,column in zip(axes,categorical_column):
    category_count=df2[column].value_counts(normalize=True)*100
    
    sns.barplot(x=category_count.index,y=category_count.values,ax=ax)
    ax.set_title(f"Bar plot for categorical column:{column}")
    ax.set_ylabel("percentage of policyholder(%)")
    ax.set_xlabel(column)
    ax.tick_params(axis='x', rotation=90)
    

plt.tight_layout()
plt.show()

# %%
crosstab=pd.crosstab(df2["income_level"],df2["insurance_plan"])

# %%
crosstab
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L         3905   288     718
# 25L - 40L         2937   183     544
# <10L              5366   370    1016
# > 40L               99   321    1806

# %%
crosstab.plot(kind='bar',stacked=True)
plt.show()

# %%
sns.heatmap(crosstab,annot=True,fmt='d')
plt.show()

# %%
df2.head(2)
# Out:
#    unnamed:_0  age  gender     region marital_status  number_of_dependants  \
# 0           4   18    Male  Northeast      Unmarried                     0
# 1           9   22  Female  Northwest      Unmarried                     0
#
#   bmi_category smoking_status employment_status income_level  income_lakhs  \
# 0   Overweight        Regular     Self-Employed        > 40L            99
# 1  Underweight     No Smoking        Freelancer         <10L             3
#
#        medical_history insurance_plan  annual_premium_amount
# 0  High blood pressure         Silver                  13365
# 1           No Disease         Silver                  11050

# %%
df2.medical_history.unique()
# Out:
# array(['High blood pressure', 'No Disease',
#        'Diabetes & High blood pressure', 'Diabetes & Heart disease',
#        'Diabetes', 'Diabetes & Thyroid', 'Heart disease', 'Thyroid',
#        'High blood pressure & Heart disease'], dtype=object)

# %% [markdown]
# # Feature Engineering

# %%
risk_score={
    'diabetes':6,
    'high blood pressure':6,
    'no disease':0,
    'thyroid':5,
    'heart disease':8,
    'none':0
}
df2[["disease1","disease2"]]=df2.medical_history.str.split("&",expand=True).apply(lambda x:x.str.lower().str.strip().fillna('none'))

# %%
df2.sample(5)
# Out:
#        unnamed:_0  age  gender     region marital_status  \
# 3435         9738   24    Male  Southeast      Unmarried
# 481          1453   21    Male  Southeast      Unmarried
# 16507       47099   19  Female  Northwest      Unmarried
# 14849       42200   22    Male  Southwest      Unmarried
# 16233       46295   23    Male  Southwest      Unmarried
#
#        number_of_dependants bmi_category smoking_status employment_status  \
# 3435                      0       Normal     No Smoking          Salaried
# 481                       1       Normal     No Smoking        Freelancer
# 16507                     1  Underweight     No Smoking          Salaried
# 14849                     1      Obesity     No Smoking        Freelancer
# 16233                     1  Underweight        Regular          Salaried
#
#       income_level  income_lakhs medical_history insurance_plan  \
# 3435     10L - 25L            24      No Disease         Bronze
# 481           <10L             9      No Disease         Bronze
# 16507    10L - 25L            12      No Disease         Bronze
# 14849         <10L             3      No Disease         Bronze
# 16233    25L - 40L            38      No Disease         Bronze
#
#        annual_premium_amount    disease1 disease2
# 3435                    8077  no disease     none
# 481                     4935  no disease     none
# 16507                   5872  no disease     none
# 14849                   7740  no disease     none
# 16233                   7173  no disease     none

# %%
df2["total_risk_score"]=df2['disease1'].map(risk_score)+df2['disease2'].map(risk_score)
df2['normalised_risk_score']=(df2["total_risk_score"]-df2['total_risk_score'].min())/(df2["total_risk_score"].max()-df2["total_risk_score"].min())

# %%
df2.sample(5)
# Out:
#        unnamed:_0  age  gender     region marital_status  \
# 1091         3134   19    Male  Northwest      Unmarried
# 15030       42713   18  Female  Southeast      Unmarried
# 8914        25236   20  Female  Southeast      Unmarried
# 10058       28478   21    Male  Southwest      Unmarried
# 7268        20511   24    Male  Southwest      Unmarried
#
#        number_of_dependants bmi_category smoking_status employment_status  \
# 1091                      1       Normal     No Smoking     Self-Employed
# 15030                     0  Underweight     No Smoking        Freelancer
# 8914                      0  Underweight     No Smoking        Freelancer
# 10058                     0   Overweight        Regular          Salaried
# 7268                      0       Normal     No Smoking          Salaried
#
#       income_level  income_lakhs medical_history insurance_plan  \
# 1091          <10L             2      No Disease         Bronze
# 15030    10L - 25L            14        Diabetes         Bronze
# 8914          <10L             3      No Disease         Bronze
# 10058        > 40L            41      No Disease         Silver
# 7268          <10L             7      No Disease         Bronze
#
#        annual_premium_amount    disease1 disease2  total_risk_score  \
# 1091                    6447  no disease     none                 0
# 15030                   4846    diabetes     none                 6
# 8914                    4427  no disease     none                 0
# 10058                  13530  no disease     none                 0
# 7268                    8679  no disease     none                 0
#
#        normalised_risk_score
# 1091                0.000000
# 15030               0.428571
# 8914                0.000000
# 10058               0.000000
# 7268                0.000000

# %%
df2.insurance_plan.unique()
# Out:
# array(['Silver', 'Bronze', 'Gold'], dtype=object)

# %%
df2.insurance_plan=df.insurance_plan.map({'Bronze':1,'Silver':2,'Gold':3})

# %%
df2.sample(5)
# Out:
#        unnamed:_0  age  gender     region marital_status  \
# 1230         3583   20  Female  Southeast      Unmarried
# 8130        22991   23  Female  Northeast      Unmarried
# 1247         3640   18  Female  Northwest        Married
# 11408       32426   24  Female  Northeast      Unmarried
# 7324        20651   21    Male  Southwest      Unmarried
#
#        number_of_dependants bmi_category smoking_status employment_status  \
# 1230                      0   Overweight     No Smoking        Freelancer
# 8130                      0  Underweight     No Smoking        Freelancer
# 1247                      3   Overweight     No Smoking          Salaried
# 11408                     1      Obesity     Occasional        Freelancer
# 7324                      0      Obesity        Regular        Freelancer
#
#       income_level  income_lakhs medical_history  insurance_plan  \
# 1230          <10L             2      No Disease               1
# 8130          <10L             6      No Disease               3
# 1247     10L - 25L            24        Diabetes               2
# 11408    10L - 25L            17      No Disease               1
# 7324          <10L             2      No Disease               1
#
#        annual_premium_amount    disease1 disease2  total_risk_score  \
# 1230                    7114  no disease     none                 0
# 8130                   12463  no disease     none                 0
# 1247                    9712    diabetes     none                 6
# 11408                   6965  no disease     none                 0
# 7324                    7230  no disease     none                 0
#
#        normalised_risk_score
# 1230                0.000000
# 8130                0.000000
# 1247                0.428571
# 11408               0.000000
# 7324                0.000000

# %%
df2.income_level.unique()
# Out:
# array(['> 40L', '<10L', '10L - 25L', '25L - 40L'], dtype=object)

# %%
df2.income_level=df2.income_level.map({'<10L':1, '10L - 25L':2, '> 40L':3, '25L - 40L':4})

# %%
nominal_col=['gender', 'region', 'marital_status','bmi_category', 'smoking_status','employment_status']

# %%
df3=pd.get_dummies(df2,columns=nominal_col,drop_first=True,dtype=int)

# %%
df3.sample(2)
# Out:
#        unnamed:_0  age  number_of_dependants  income_level  income_lakhs  \
# 6552        18528   20                     2             2            16
# 16835       48036   18                     1             2            25
#
#       medical_history  insurance_plan  annual_premium_amount    disease1  \
# 6552       No Disease               1                   5892  no disease
# 16835      No Disease               1                   6575  no disease
#
#       disease2  ...  region_Southeast  region_Southwest  \
# 6552      none  ...                 0                 1
# 16835     none  ...                 0                 0
#
#        marital_status_Unmarried  bmi_category_Obesity  \
# 6552                          1                     0
# 16835                         1                     0
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# 6552                         1                         0
# 16835                        0                         1
#
#        smoking_status_Occasional  smoking_status_Regular  \
# 6552                           0                       0
# 16835                          0                       0
#
#        employment_status_Salaried  employment_status_Self-Employed
# 6552                            0                                0
# 16835                           0                                0
#
# [2 rows x 24 columns]

# %%
df4=df3.drop(["medical_history","disease1","disease2","total_risk_score"],axis=1)

# %%
df4.sample(1)
# Out:
#       unnamed:_0  age  number_of_dependants  income_level  income_lakhs  \
# 7126       20118   24                     2             2            21
#
#       insurance_plan  annual_premium_amount  normalised_risk_score  \
# 7126               1                   5731                    0.0
#
#       gender_Male  region_Northwest  region_Southeast  region_Southwest  \
# 7126            0                 0                 0                 0
#
#       marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# 7126                         1                     0                        0
#
#       bmi_category_Underweight  smoking_status_Occasional  \
# 7126                         0                          0
#
#       smoking_status_Regular  employment_status_Salaried  \
# 7126                       0                           0
#
#       employment_status_Self-Employed
# 7126                                0

# %%
sns.heatmap(df4.corr(),annot=True)
# Out:
# <Axes: >

# %%
X=df4.drop('annual_premium_amount',axis=1)
y=df4['annual_premium_amount']

# %%
X.head(2)
# Out:
#    unnamed:_0  age  number_of_dependants  income_level  income_lakhs  \
# 0           4   18                     0             3            99
# 1           9   22                     0             1             3
#
#    insurance_plan  normalised_risk_score  gender_Male  region_Northwest  \
# 0               2               0.428571            1                 0
# 1               2               0.000000            0                 1
#
#    region_Southeast  region_Southwest  marital_status_Unmarried  \
# 0                 0                 0                         1
# 1                 0                 0                         1
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 0                     0                        1                         0
# 1                     0                        0                         1
#
#    smoking_status_Occasional  smoking_status_Regular  \
# 0                          0                       1
# 1                          0                       0
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           0                                1
# 1                           0                                0

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
cols_to_scale=['age','number_of_dependants','income_level','income_lakhs','insurance_plan']
X[cols_to_scale]=scalar.fit_transform(X[cols_to_scale])

# %%
X.head()
# Out:
#    unnamed:_0       age  number_of_dependants  income_level  income_lakhs  \
# 0           4  0.000000              0.000000      0.666667      0.989899
# 1           9  0.666667              0.000000      0.000000      0.020202
# 2          10  0.500000              0.000000      0.666667      0.969697
# 3          19  0.333333              0.666667      0.333333      0.131313
# 4          21  0.666667              0.000000      1.000000      0.292929
#
#    insurance_plan  normalised_risk_score  gender_Male  region_Northwest  \
# 0             0.5               0.428571            1                 0
# 1             0.5               0.000000            0                 1
# 2             0.5               0.000000            0                 0
# 3             0.0               0.000000            1                 0
# 4             1.0               0.428571            0                 0
#
#    region_Southeast  region_Southwest  marital_status_Unmarried  \
# 0                 0                 0                         1
# 1                 0                 0                         1
# 2                 1                 0                         1
# 3                 1                 0                         1
# 4                 0                 1                         1
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 0                     0                        1                         0
# 1                     0                        0                         1
# 2                     0                        0                         0
# 3                     0                        1                         0
# 4                     0                        0                         1
#
#    smoking_status_Occasional  smoking_status_Regular  \
# 0                          0                       1
# 1                          0                       0
# 2                          0                       1
# 3                          0                       0
# 4                          0                       1
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           0                                1
# 1                           0                                0
# 2                           1                                0
# 3                           0                                0
# 4                           0                                0

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df=pd.DataFrame()
    vif_df['column']=data.columns
    vif_df['Vif']=[variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X)
# Out:
#                              column       Vif
# 0                        unnamed:_0  3.727265
# 1                               age  3.082112
# 2              number_of_dependants  1.960522
# 3                      income_level  3.910721
# 4                      income_lakhs  4.331965
# 5                    insurance_plan  1.655870
# 6             normalised_risk_score  1.155798
# 7                       gender_Male  2.325873
# 8                  region_Northwest  2.142824
# 9                  region_Southeast  2.984866
# 10                 region_Southwest  2.757165
# 11         marital_status_Unmarried  8.228590
# 12             bmi_category_Obesity  1.110278
# 13          bmi_category_Overweight  1.229612
# 14         bmi_category_Underweight  1.366431
# 15        smoking_status_Occasional  1.134175
# 16           smoking_status_Regular  1.390663
# 17       employment_status_Salaried  1.689459
# 18  employment_status_Self-Employed  1.296446

# %% [markdown]
# ###### we will drop columns only if the vif is greater than 10 and columns are to be dropped one by one and then checked for vif however we are dropping vif to match lecture requirement
# | VIF Value  | Interpretation                                | Action Needed?               |
# | ---------- | --------------------------------------------- | ---------------------------- |
# | **1**      | No multicollinearity                          | ✅ Ideal                      |
# | **1 - 5**  | Moderate correlation                          | ✅ Usually okay               |
# | **5 - 10** | High correlation (possible multicollinearity) | ⚠️ Investigate further       |
# | **> 10**   | Severe multicollinearity                      | ❌ Remove or combine features |

# %%
calculate_vif(X.drop("income_level",axis=1))
# Out:
#                              column       Vif
# 0                        unnamed:_0  3.725505
# 1                               age  3.079826
# 2              number_of_dependants  1.953804
# 3                      income_lakhs  2.292802
# 4                    insurance_plan  1.595747
# 5             normalised_risk_score  1.155554
# 6                       gender_Male  2.308682
# 7                  region_Northwest  2.140902
# 8                  region_Southeast  2.981246
# 9                  region_Southwest  2.755111
# 10         marital_status_Unmarried  8.155934
# 11             bmi_category_Obesity  1.110272
# 12          bmi_category_Overweight  1.229436
# 13         bmi_category_Underweight  1.366431
# 14        smoking_status_Occasional  1.134175
# 15           smoking_status_Regular  1.390355
# 16       employment_status_Salaried  1.671733
# 17  employment_status_Self-Employed  1.294292

# %%
X_reduced=X.drop('income_level',axis=1)

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X_reduced,y,test_size=0.3,random_state=10)

# %%
print(f"X_train:{X_train.shape}")
print(f"X_test:{X_test.shape}")
print(f"y_train:{y_train.shape}")
print(f"y_test:{y_test.shape}")
# Out:
# X_train:(12287, 18)
# X_test:(5266, 18)
# y_train:(12287,)
# y_test:(5266,)

# %%
model_lr=LinearRegression()
model_lr.fit(X_train,y_train)
y_pred=model_lr.predict(X_test)


train_score=model_lr.score(X_train,y_train)
test_score=model_lr.score(X_test,y_test)
train_score,test_score
# Out:
# (0.6061686013149474, 0.6063015949621149)

# %%
model_lr.intercept_
# Out:
# 6613.920549279674

# %%
model_lr.coef_
# Out:
# array([-1.12219286e-03,  3.32899405e+01, -4.46628550e+01,  2.99915698e+01,
#         7.01161200e+03,  1.03944738e+03, -4.09983185e+01, -9.65359759e+01,
#         1.33554150e+00, -4.26958150e+01, -6.58610229e+01,  7.92146556e+02,
#         4.08495114e+02,  1.50398011e+02,  2.96113510e+02,  6.47089031e+02,
#        -3.43006124e+01,  6.15929384e+00])

# %%
X_test.columns
# Out:
# Index(['unnamed:_0', 'age', 'number_of_dependants', 'income_lakhs',
#        'insurance_plan', 'normalised_risk_score', 'gender_Male',
#        'region_Northwest', 'region_Southeast', 'region_Southwest',
#        'marital_status_Unmarried', 'bmi_category_Obesity',
#        'bmi_category_Overweight', 'bmi_category_Underweight',
#        'smoking_status_Occasional', 'smoking_status_Regular',
#        'employment_status_Salaried', 'employment_status_Self-Employed'],
#       dtype='object')

# %%
coef_df=pd.DataFrame(model_lr.coef_,X_test.columns,columns=["coefficient"]).reset_index()

coef_df=coef_df.sort_values(by='coefficient',ascending=False)
coef_df


plt.figure(figsize=(8,8))
sns.barplot(x=coef_df["coefficient"],y=coef_df["index"])
plt.show()

# %%
model_ridge=Ridge()

# %%
model_ridge=Ridge()
model_ridge.fit(X_train,y_train)
train_score=model_ridge.score(X_train,y_train)
test_score=model_ridge.score(X_test,y_test)
train_score,test_score
# Out:
# (0.6061680230589785, 0.6063113698602562)

# %%
from xgboost import XGBRegressor

# %%
from xgboost import XGBRegressor
model_xg=XGBRegressor()
model_xg.fit(X_train,y_train)
y_pred=model_xg.predict(X_test)
train_score=model_xg.score(X_train,y_train)
test_score=model_xg.score(X_test,y_test)
train_score,test_score
# Out:
# (0.7783702611923218, 0.5548527240753174)

# %%
rsme=root_mean_squared_error(y_test,y_pred)

# %%
rsme
# Out:
# 1844.5510248653627

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
print(np.sqrt(mse))
# Out:
# 3402368.48333186
# 1844.5510248653627

# %%
model_xgb=XGBRegressor()
from sklearn.model_selection import RandomizedSearchCV
param_grid={
    'n_estimators':[20,40,50],
    'learning_rate':[0.01,0.1,0.2],
    'max_depth':[3,4,5]
}
random_search=RandomizedSearchCV(model_xgb,param_grid,n_iter=10,cv=3,scoring='r2')

# %%
random_search.fit(X_train,y_train)
random_search.best_score_
# Out:
# 0.5997427900632223

# %%
random_search.best_params_
# Out:
# {'n_estimators': 40, 'max_depth': 5, 'learning_rate': 0.1}

# %%
best_model=model_lr

# %%
best_model
# Out:
# LinearRegression()

# %% [markdown]
# # Error Analysis

# %%
res=pd.DataFrame({
    'y_test':y_test,
    'y_pred':y_pred,
    
})

# %%
res['residuals']=res['y_pred']-res['y_test']
res['residual%']=res['residuals']*100/res['y_test']
res.head()
# Out:
#        y_test        y_pred    residuals  residual%
# 5184     9525   6949.747559 -2575.252441 -27.036771
# 4370    11900  12194.597656   294.597656   2.475611
# 10550    5606   6291.590332   685.590332  12.229581
# 15707    8438   4987.853516 -3450.146484 -40.888202
# 4692     7626   7652.472168    26.472168   0.347130

# %%
sns.histplot(res['residual%'],kde=True)
# Out:
# <Axes: xlabel='residual%', ylabel='Count'>

# %%
extreme_error=10
extreme_error_threshold=res[np.abs(res['residual%'])>extreme_error]

# %%
len(extreme_error_threshold)*100/len(res)
# Out:
# 72.73072540827953

# %%
extreme_error=50
extreme_error_threshold=res[np.abs(res['residual%'])>extreme_error]

# %%
extreme_error_threshold.sort_values(by='residual%',ascending=False)
# Out:
#        y_test        y_pred    residuals   residual%
# 17464    3936   9181.973633  5245.973633  133.281850
# 22       4683  10046.393555  5363.393555  114.529010
# 10390    3546   7241.900391  3695.900391  104.227309
# 15564    3664   7456.005371  3792.005371  103.493596
# 8878     3649   7318.917480  3669.917480  100.573239
# ...       ...           ...          ...         ...
# 14296    4594   6900.394043  2306.394043   50.204485
# 15377    4790   7192.310059  2402.310059   50.152611
# 3171     4467   6705.433105  2238.433105   50.110434
# 12073    5651   8481.375977  2830.375977   50.086285
# 4177    10560   5230.846191 -5329.153809  -50.465472
#
# [465 rows x 4 columns]

# %%
extreme_error_threshold.index
# Out:
# Index([14039,  8650,  6718,  1369,  1791,  6564,  1331, 10410, 15200,  9160,
#        ...
#         6161, 13077, 10246, 16643,  6713,  7600, 16627,  3417, 14727,  5813],
#       dtype='int64', length=465)

# %%
extreme_error_df=X_test.loc[extreme_error_threshold.index]

# %%
for i in X_test.columns:
    plt.title(f"Error Analysis of {i} column")

    sns.histplot(X_test[i],label='overall',kde=True)
    sns.histplot(extreme_error_df[i],label='extreme error',kde=True)
    plt.legend()
    plt.show()

# %% [markdown]
# #### so we can find there is a error is higher in Age column

# %%
sns.histplot(extreme_error_df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
cols_to_scale
# Out:
# ['age',
#  'number_of_dependants',
#  'income_level',
#  'income_lakhs',
#  'insurance_plan']

# %%
extreme_error_df['income_level']=-1

# %%
extreme_error_df
# Out:
#        unnamed:_0       age  number_of_dependants  income_lakhs  \
# 14039       39828  1.000000              0.000000      0.080808
# 8650        24502  0.666667              0.000000      0.131313
# 6718        18988  1.000000              0.000000      0.090909
# 1369         3972  0.833333              0.000000      0.050505
# 1791         5217  0.166667              0.333333      0.181818
# ...           ...       ...                   ...           ...
# 7600        21453  0.333333              0.000000      0.131313
# 16627       47419  0.000000              0.000000      0.222222
# 3417         9686  0.166667              0.000000      0.191919
# 14727       41861  0.833333              0.666667      0.383838
# 5813        16413  0.166667              0.000000      0.252525
#
#        insurance_plan  normalised_risk_score  gender_Male  region_Northwest  \
# 14039             0.0                    0.0            1                 0
# 8650              0.0                    0.0            1                 0
# 6718              0.0                    0.0            1                 0
# 1369              0.0                    0.0            1                 0
# 1791              0.0                    0.0            0                 1
# ...               ...                    ...          ...               ...
# 7600              0.0                    0.0            0                 0
# 16627             0.0                    0.0            0                 1
# 3417              0.0                    0.0            1                 0
# 14727             0.0                    0.0            1                 0
# 5813              0.0                    0.0            1                 0
#
#        region_Southeast  region_Southwest  marital_status_Unmarried  \
# 14039                 1                 0                         1
# 8650                  1                 0                         1
# 6718                  1                 0                         1
# 1369                  0                 1                         1
# 1791                  0                 0                         1
# ...                 ...               ...                       ...
# 7600                  0                 1                         1
# 16627                 0                 0                         1
# 3417                  0                 1                         1
# 14727                 1                 0                         1
# 5813                  1                 0                         1
#
#        bmi_category_Obesity  bmi_category_Overweight  \
# 14039                     0                        0
# 8650                      0                        0
# 6718                      0                        0
# 1369                      0                        0
# 1791                      0                        0
# ...                     ...                      ...
# 7600                      0                        1
# 16627                     0                        1
# 3417                      0                        1
# 14727                     0                        0
# 5813                      0                        0
#
#        bmi_category_Underweight  smoking_status_Occasional  \
# 14039                         0                          0
# 8650                          0                          0
# 6718                          0                          0
# 1369                          0                          0
# 1791                          0                          0
# ...                         ...                        ...
# 7600                          0                          1
# 16627                         0                          0
# 3417                          0                          0
# 14727                         1                          0
# 5813                          1                          0
#
#        smoking_status_Regular  employment_status_Salaried  \
# 14039                       1                           0
# 8650                        0                           0
# 6718                        0                           0
# 1369                        0                           0
# 1791                        0                           0
# ...                       ...                         ...
# 7600                        0                           1
# 16627                       0                           0
# 3417                        0                           0
# 14727                       0                           0
# 5813                        0                           1
#
#        employment_status_Self-Employed  income_level
# 14039                                0            -1
# 8650                                 0            -1
# 6718                                 1            -1
# 1369                                 0            -1
# 1791                                 0            -1
# ...                                ...           ...
# 7600                                 0            -1
# 16627                                0            -1
# 3417                                 0            -1
# 14727                                1            -1
# 5813                                 0            -1
#
# [465 rows x 19 columns]

# %%
df_reversed=pd.DataFrame()
df_reversed[cols_to_scale]=scalar.inverse_transform(extreme_error_df[cols_to_scale])
df_reversed
# Out:
#       age  number_of_dependants  income_level  income_lakhs  insurance_plan
# 0    24.0                   0.0          -2.0           9.0             1.0
# 1    22.0                   0.0          -2.0          14.0             1.0
# 2    24.0                   0.0          -2.0          10.0             1.0
# 3    23.0                   0.0          -2.0           6.0             1.0
# 4    19.0                   1.0          -2.0          19.0             1.0
# ..    ...                   ...           ...           ...             ...
# 460  20.0                   0.0          -2.0          14.0             1.0
# 461  18.0                   0.0          -2.0          23.0             1.0
# 462  19.0                   0.0          -2.0          20.0             1.0
# 463  23.0                   2.0          -2.0          39.0             1.0
# 464  19.0                   0.0          -2.0          26.0             1.0
#
# [465 rows x 5 columns]

# %%
df_reversed.age.quantile(0.97)
# Out:
# 24.0

# %% [markdown]
# # model Segmentation

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ankit\Python Project\Helth insurance project
