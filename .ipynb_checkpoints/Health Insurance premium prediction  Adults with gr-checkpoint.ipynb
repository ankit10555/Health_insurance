# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as  plt
import seaborn as sns
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error,mean_squared_error
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV,RandomizedSearchCV

# %%
df=pd.read_excel(r"C:\Users\ankit\Python Project\Helth insurance project\premiums_old.xlsx")

# %%
df.head(2)
# Out:
#    Unnamed: 0  Age  Gender     Region Marital_status  Number Of Dependants  \
# 0           0   26    Male  Northwest      Unmarried                     0
# 1           1   29  Female  Southeast        Married                     2
#
#   BMI_Category Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0       Normal     No Smoking          Salaried         <10L             6
# 1      Obesity        Regular          Salaried         <10L             6
#
#   Medical History Insurance_Plan  Annual_Premium_Amount
# 0        Diabetes         Bronze                   9053
# 1        Diabetes         Bronze                  16339

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Gender', 'Region', 'Marital_status',
#        'Number Of Dependants', 'BMI_Category', 'Smoking_Status',
#        'Employment_Status', 'Income_Level', 'Income_Lakhs', 'Medical History',
#        'Insurance_Plan', 'Annual_Premium_Amount'],
#       dtype='object')

# %%
df.shape
# Out:
# (29904, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29904 entries, 0 to 29903
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             29904 non-null  int64
#  1   Age                    29904 non-null  int64
#  2   Gender                 29904 non-null  object
#  3   Region                 29904 non-null  object
#  4   Marital_status         29904 non-null  object
#  5   Number Of Dependants   29904 non-null  int64
#  6   BMI_Category           29904 non-null  object
#  7   Smoking_Status         29895 non-null  object
#  8   Employment_Status      29903 non-null  object
#  9   Income_Level           29895 non-null  object
#  10  Income_Lakhs           29904 non-null  int64
#  11  Medical History        29904 non-null  object
#  12  Insurance_Plan         29904 non-null  object
#  13  Annual_Premium_Amount  29904 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0           Age  Number Of Dependants  Income_Lakhs  \
# count  29904.000000  29904.000000          29904.000000  29904.000000
# mean   25025.682952     43.396536              2.380116     23.362059
# std    14431.538080     13.411893              1.431140     24.737076
# min        0.000000     26.000000             -3.000000      1.000000
# 25%    12604.250000     34.000000              1.000000      7.000000
# 50%    25063.500000     42.000000              3.000000     17.000000
# 75%    37560.000000     52.000000              3.000000     32.000000
# max    49999.000000    356.000000              5.000000    930.000000
#
#        Annual_Premium_Amount
# count           29904.000000
# mean            20893.036684
# std              6935.844219
# min              3625.000000
# 25%             15698.000000
# 50%             20489.000000
# 75%             26360.000000
# max             43471.000000

# %%
df.columns=df.columns.str.replace(" ","_").str.lower()

# %%
df.columns
# Out:
# Index(['unnamed:_0', 'age', 'gender', 'region', 'marital_status',
#        'number_of_dependants', 'bmi_category', 'smoking_status',
#        'employment_status', 'income_level', 'income_lakhs', 'medical_history',
#        'insurance_plan', 'annual_premium_amount'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# unnamed:_0               0
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           9
# employment_status        1
# income_level             9
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# dtype: int64

# %% [markdown]
# ## Handling nulls and duplicates

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#          unnamed:_0           age  number_of_dependants  income_lakhs  \
# count  29886.000000  29886.000000          29886.000000  29886.000000
# mean   25027.094091     43.396105              2.379910     23.364184
# std    14432.632929     13.412657              1.431201     24.740339
# min        0.000000     26.000000             -3.000000      1.000000
# 25%    12599.250000     34.000000              1.000000      7.000000
# 50%    25067.500000     42.000000              3.000000     17.000000
# 75%    37563.750000     52.000000              3.000000     32.000000
# max    49999.000000    356.000000              5.000000    930.000000
#
#        annual_premium_amount
# count           29886.000000
# mean            20892.303821
# std              6936.813440
# min              3625.000000
# 25%             15697.250000
# 50%             20489.000000
# 75%             26360.000000
# max             43471.000000

# %%
df[df.number_of_dependants<0]["number_of_dependants"].value_counts()
# Out:
# number_of_dependants
# -1    30
# -3    20
# Name: count, dtype: int64

# %%
df.number_of_dependants=np.abs(df.number_of_dependants)

# %%
df.number_of_dependants.describe()
# Out:
# count    29886.000000
# mean         2.385933
# std          1.421137
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          3.000000
# max          5.000000
# Name: number_of_dependants, dtype: float64

# %% [markdown]
# # Outlier Treatment

# %%
def bplot(data):

    q1=data.quantile(0.25)
    q3=data.quantile(0.75)
    IQR=q3-q1
    lower=q1-1.5*IQR
    upper=q3+1.5*IQR

    
    sns.boxplot(data)
    plt.axhline(lower, color='red', linestyle='--', label='Lower Bound')
    plt.axhline(upper, color='blue', linestyle='--', label='Upper Bound')
    plt.legend()
    plt.show()

# %%
for c in df.select_dtypes([float,int]).columns:
    bplot(df[c])

# %%
df1=df[df.age<=100].copy()

# %% [markdown]
# # univariate analysis

# %%
sns.histplot(df1.income_lakhs,kde=True)
# Out:
# <Axes: xlabel='income_lakhs', ylabel='Count'>

# %%
def iqr_bounds(data):
    q1=data.quantile(0.25)
    q3=data.quantile(0.75)
    IQR=q3-q1
    lower=q1-1.5*IQR
    upper=q3+1.5*IQR
    return upper,lower

# %%
df2=df1[df1.income_lakhs<=df1.income_lakhs.quantile(0.999)].copy()

# %%
df2.describe()
# Out:
#          unnamed:_0           age  number_of_dependants  income_lakhs  \
# count  29822.000000  29822.000000          29822.000000  29822.000000
# mean   25030.357152     43.094896              2.387734     23.226343
# std    14431.397026     11.042430              1.420644     22.455408
# min        0.000000     26.000000              0.000000      1.000000
# 25%    12605.250000     34.000000              1.000000      7.000000
# 50%    25070.000000     42.000000              3.000000     17.000000
# 75%    37565.500000     52.000000              3.000000     32.000000
# max    49999.000000     72.000000              5.000000    100.000000
#
#        annual_premium_amount
# count           29822.000000
# mean            20900.689223
# std              6928.192115
# min              6538.000000
# 25%             15705.250000
# 50%             20495.500000
# 75%             26360.000000
# max             43471.000000

# %%
fig,axes=plt.subplots(2,2,figsize=(18,18))
axes=axes.flatten()



for ax,col in zip(axes,df2.select_dtypes([float,int]).columns):
    
    
    plt.title(f"Histogam of {col}")
    sns.histplot(df2[col],kde=True,ax=ax)
    
plt.tight_layout()    
plt.show()

# %% [markdown]
# # Bivariate analysis

# %%
for col in df2.select_dtypes([float,int]).columns:
    if col=="annual_premium_amount":
        continue
    sns.scatterplot(x=df2[col],y=df2.annual_premium_amount)
    plt.show()

# %%
for col in df2.select_dtypes('object').columns:
    print(f"{col}:",df2[col].unique())
# Out:
# gender: ['Male' 'Female']
# region: ['Northwest' 'Southeast' 'Northeast' 'Southwest']
# marital_status: ['Unmarried' 'Married']
# bmi_category: ['Normal' 'Obesity' 'Overweight' 'Underweight']
# smoking_status: ['No Smoking' 'Regular' 'Occasional' 'Does Not Smoke' 'Not Smoking'
#  'Smoking=0']
# employment_status: ['Salaried' 'Self-Employed' 'Freelancer']
# income_level: ['<10L' '10L - 25L' '> 40L' '25L - 40L']
# medical_history: ['Diabetes' 'High blood pressure' 'No Disease'
#  'Diabetes & High blood pressure' 'Thyroid' 'Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid'
#  'Diabetes & Heart disease']
# insurance_plan: ['Bronze' 'Silver' 'Gold']

# %%
df2["smoking_status"]=df2["smoking_status"].replace({'Smoking=0':'No Smoking',
                                   'Does Not Smoke':'No Smoking',
                                   'Not Smoking':'No Smoking'}
                                   )

# %%
pct_count=df2["gender"].value_counts(normalize=True)

# %%
sns.barplot(x=pct_count.index,y=pct_count.values)
plt.show()

# %%
len(df2.select_dtypes('object').columns)
# Out:
# 9

# %%
categorical_column=df2.select_dtypes(object).columns
categorical_column
# Out:
# Index(['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status',
#        'employment_status', 'income_level', 'medical_history',
#        'insurance_plan'],
#       dtype='object')

# %%
fig,axes=plt.subplots(3,3,figsize=(18,18))
axes=axes.flatten()

for ax,column in zip(axes,categorical_column):
    category_count=df2[column].value_counts(normalize=True)*100
    
    sns.barplot(x=category_count.index,y=category_count.values,ax=ax)
    ax.set_title(f"Bar plot for categorical column:{column}")
    ax.set_ylabel("percentage of policyholder(%)")
    ax.set_xlabel(column)
    ax.tick_params(axis='x', rotation=90)
    

plt.tight_layout()
plt.show()

# %%
crosstab=pd.crosstab(df2["income_level"],df2["insurance_plan"])

# %%
crosstab
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L          799  3554    4354
# 25L - 40L          301  2631    3142
# <10L              6054   527    4341
# > 40L              214  3287     618

# %%
crosstab.plot(kind='bar',stacked=True)
plt.show()

# %%
sns.heatmap(crosstab,annot=True,fmt='d')
plt.show()

# %%
df2.head(2)
# Out:
#    unnamed:_0  age  gender     region marital_status  number_of_dependants  \
# 0           0   26    Male  Northwest      Unmarried                     0
# 1           1   29  Female  Southeast        Married                     2
#
#   bmi_category smoking_status employment_status income_level  income_lakhs  \
# 0       Normal     No Smoking          Salaried         <10L             6
# 1      Obesity        Regular          Salaried         <10L             6
#
#   medical_history insurance_plan  annual_premium_amount
# 0        Diabetes         Bronze                   9053
# 1        Diabetes         Bronze                  16339

# %%
df2.medical_history.unique()
# Out:
# array(['Diabetes', 'High blood pressure', 'No Disease',
#        'Diabetes & High blood pressure', 'Thyroid', 'Heart disease',
#        'High blood pressure & Heart disease', 'Diabetes & Thyroid',
#        'Diabetes & Heart disease'], dtype=object)

# %% [markdown]
# # Feature Engineering

# %%
risk_score={
    'diabetes':6,
    'high blood pressure':6,
    'no disease':0,
    'thyroid':5,
    'heart disease':8,
    'none':0
}
df2[["disease1","disease2"]]=df2.medical_history.str.split("&",expand=True).apply(lambda x:x.str.lower().str.strip().fillna('none'))

# %%
df2.sample(5)
# Out:
#        unnamed:_0  age  gender     region marital_status  \
# 1861         3081   30  Female  Southeast      Unmarried
# 13552       22748   47  Female  Southeast        Married
# 21492       35972   26    Male  Southeast        Married
# 4270         7104   38    Male  Northwest        Married
# 26545       44328   26    Male  Southeast      Unmarried
#
#        number_of_dependants bmi_category smoking_status employment_status  \
# 1861                      0       Normal     No Smoking     Self-Employed
# 13552                     3       Normal     No Smoking          Salaried
# 21492                     3      Obesity     Occasional          Salaried
# 4270                      3  Underweight        Regular        Freelancer
# 26545                     2       Normal        Regular          Salaried
#
#       income_level  income_lakhs                 medical_history  \
# 1861          <10L             2                      No Disease
# 13552         <10L             9                      No Disease
# 21492         <10L             1             High blood pressure
# 4270     10L - 25L            24                        Diabetes
# 26545    10L - 25L            13  Diabetes & High blood pressure
#
#       insurance_plan  annual_premium_amount             disease1  \
# 1861          Bronze                   7332           no disease
# 13552         Silver                  16258           no disease
# 21492         Bronze                  13901  high blood pressure
# 4270          Silver                  18947             diabetes
# 26545         Silver                  20996             diabetes
#
#                   disease2
# 1861                  none
# 13552                 none
# 21492                 none
# 4270                  none
# 26545  high blood pressure

# %%
df2["total_risk_score"]=df2['disease1'].map(risk_score)+df2['disease2'].map(risk_score)
df2['normalised_risk_score']=(df2["total_risk_score"]-df2['total_risk_score'].min())/(df2["total_risk_score"].max()-df2["total_risk_score"].min())

# %%
df2.sample(5)
# Out:
#        unnamed:_0  age  gender     region marital_status  \
# 28531       47664   70  Female  Southeast        Married
# 22048       36902   30  Female  Southwest      Unmarried
# 5203         8694   41    Male  Southwest        Married
# 8411        14131   52  Female  Northwest        Married
# 19536       32673   56  Female  Northwest        Married
#
#        number_of_dependants bmi_category smoking_status employment_status  \
# 28531                     1  Underweight     No Smoking     Self-Employed
# 22048                     1       Normal     Occasional          Salaried
# 5203                      5       Normal        Regular     Self-Employed
# 8411                      3      Obesity     Occasional     Self-Employed
# 19536                     2      Obesity     No Smoking          Salaried
#
#       income_level  income_lakhs           medical_history insurance_plan  \
# 28531    25L - 40L            28       High blood pressure           Gold
# 22048    10L - 25L            25                  Diabetes         Silver
# 5203     10L - 25L            24                  Diabetes         Silver
# 8411          <10L             3  Diabetes & Heart disease         Silver
# 19536         <10L             7                  Diabetes         Silver
#
#        annual_premium_amount             disease1       disease2  \
# 28531                  32664  high blood pressure           none
# 22048                  16605             diabetes           none
# 5203                   18945             diabetes           none
# 8411                   27967             diabetes  heart disease
# 19536                  22993             diabetes           none
#
#        total_risk_score  normalised_risk_score
# 28531                 6               0.428571
# 22048                 6               0.428571
# 5203                  6               0.428571
# 8411                 14               1.000000
# 19536                 6               0.428571

# %%
df2.insurance_plan.unique()
# Out:
# array(['Bronze', 'Silver', 'Gold'], dtype=object)

# %%
df2.insurance_plan=df.insurance_plan.map({'Bronze':1,'Silver':2,'Gold':3})

# %%
df2.sample(5)
# Out:
#        unnamed:_0  age  gender     region marital_status  \
# 12825       21518   39  Female  Southwest        Married
# 13791       23156   36  Female  Northwest      Unmarried
# 21227       35525   43  Female  Northeast        Married
# 26229       43801   34  Female  Northwest      Unmarried
# 6747        11388   32  Female  Southwest        Married
#
#        number_of_dependants bmi_category smoking_status employment_status  \
# 12825                     3   Overweight        Regular          Salaried
# 13791                     0       Normal     No Smoking        Freelancer
# 21227                     3      Obesity        Regular          Salaried
# 26229                     1   Overweight        Regular          Salaried
# 6747                      3       Normal     No Smoking     Self-Employed
#
#       income_level  income_lakhs      medical_history  insurance_plan  \
# 12825         <10L             8              Thyroid               1
# 13791    25L - 40L            27             Diabetes               1
# 21227    10L - 25L            13           No Disease               2
# 26229         <10L             6        Heart disease               1
# 6747          <10L             7  High blood pressure               2
#
#        annual_premium_amount             disease1 disease2  total_risk_score  \
# 12825                  13993              thyroid     none                 5
# 13791                   9371             diabetes     none                 6
# 21227                  20141           no disease     none                 0
# 26229                  18020        heart disease     none                 8
# 6747                   15226  high blood pressure     none                 6
#
#        normalised_risk_score
# 12825               0.357143
# 13791               0.428571
# 21227               0.000000
# 26229               0.571429
# 6747                0.428571

# %%
df2.income_level.unique()
# Out:
# array(['<10L', '10L - 25L', '> 40L', '25L - 40L'], dtype=object)

# %%
df2.income_level=df2.income_level.map({'<10L':1, '10L - 25L':2, '> 40L':3, '25L - 40L':4})

# %%
nominal_col=['gender', 'region', 'marital_status','bmi_category', 'smoking_status','employment_status']

# %%
df3=pd.get_dummies(df2,columns=nominal_col,drop_first=True,dtype=int)

# %%
df3.sample(2)
# Out:
#        unnamed:_0  age  number_of_dependants  income_level  income_lakhs  \
# 27973       46730   32                     5             3            95
# 21709       36331   48                     4             2            15
#
#                       medical_history  insurance_plan  annual_premium_amount  \
# 27973                        Diabetes               3                  23077
# 21709  Diabetes & High blood pressure               1                  15862
#
#        disease1             disease2  ...  region_Southeast  region_Southwest  \
# 27973  diabetes                 none  ...                 1                 0
# 21709  diabetes  high blood pressure  ...                 1                 0
#
#        marital_status_Unmarried  bmi_category_Obesity  \
# 27973                         0                     0
# 21709                         0                     0
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# 27973                        0                         1
# 21709                        0                         0
#
#        smoking_status_Occasional  smoking_status_Regular  \
# 27973                          0                       0
# 21709                          0                       1
#
#        employment_status_Salaried  employment_status_Self-Employed
# 27973                           1                                0
# 21709                           0                                1
#
# [2 rows x 24 columns]

# %%
df4=df3.drop(["medical_history","disease1","disease2","total_risk_score"],axis=1)

# %%
df4.sample(1)
# Out:
#       unnamed:_0  age  number_of_dependants  income_level  income_lakhs  \
# 6780       11438   31                     3             2            19
#
#       insurance_plan  annual_premium_amount  normalised_risk_score  \
# 6780               2                  18766               0.428571
#
#       gender_Male  region_Northwest  region_Southeast  region_Southwest  \
# 6780            1                 0                 0                 1
#
#       marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# 6780                         0                     0                        0
#
#       bmi_category_Underweight  smoking_status_Occasional  \
# 6780                         0                          0
#
#       smoking_status_Regular  employment_status_Salaried  \
# 6780                       1                           0
#
#       employment_status_Self-Employed
# 6780                                1

# %%
sns.heatmap(df4.corr(),annot=True)
# Out:
# <Axes: >

# %%
X=df4.drop('annual_premium_amount',axis=1)
y=df4['annual_premium_amount']

# %%
X.head(2)
# Out:
#    unnamed:_0  age  number_of_dependants  income_level  income_lakhs  \
# 0           0   26                     0             1             6
# 1           1   29                     2             1             6
#
#    insurance_plan  normalised_risk_score  gender_Male  region_Northwest  \
# 0               1               0.428571            1                 1
# 1               1               0.428571            0                 0
#
#    region_Southeast  region_Southwest  marital_status_Unmarried  \
# 0                 0                 0                         1
# 1                 1                 0                         0
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 0                     0                        0                         0
# 1                     1                        0                         0
#
#    smoking_status_Occasional  smoking_status_Regular  \
# 0                          0                       0
# 1                          0                       1
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           1                                0
# 1                           1                                0

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
cols_to_scale=['age','number_of_dependants','income_level','income_lakhs','insurance_plan']
X[cols_to_scale]=scalar.fit_transform(X[cols_to_scale])

# %%
X.head()
# Out:
#    unnamed:_0       age  number_of_dependants  income_level  income_lakhs  \
# 0           0  0.000000                   0.0      0.000000      0.050505
# 1           1  0.065217                   0.4      0.000000      0.050505
# 2           2  0.500000                   0.4      0.333333      0.191919
# 3           3  0.086957                   0.6      0.666667      0.767677
# 4           5  0.652174                   0.6      0.333333      0.131313
#
#    insurance_plan  normalised_risk_score  gender_Male  region_Northwest  \
# 0             0.0               0.428571            1                 1
# 1             0.0               0.428571            0                 0
# 2             0.5               0.428571            0                 0
# 3             1.0               0.000000            0                 0
# 4             0.0               0.428571            1                 0
#
#    region_Southeast  region_Southwest  marital_status_Unmarried  \
# 0                 0                 0                         1
# 1                 1                 0                         0
# 2                 0                 0                         0
# 3                 1                 0                         0
# 4                 0                 0                         0
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 0                     0                        0                         0
# 1                     1                        0                         0
# 2                     0                        0                         0
# 3                     0                        0                         0
# 4                     1                        0                         0
#
#    smoking_status_Occasional  smoking_status_Regular  \
# 0                          0                       0
# 1                          0                       1
# 2                          0                       0
# 3                          0                       0
# 4                          1                       0
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           1                                0
# 1                           1                                0
# 2                           0                                1
# 3                           1                                0
# 4                           0                                1

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df=pd.DataFrame()
    vif_df['column']=data.columns
    vif_df['Vif']=[variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X)
# Out:
#                              column       Vif
# 0                        unnamed:_0  3.708663
# 1                               age  3.918273
# 2              number_of_dependants  6.586035
# 3                      income_level  4.105058
# 4                      income_lakhs  3.798575
# 5                    insurance_plan  4.932261
# 6             normalised_risk_score  3.851385
# 7                       gender_Male  2.600772
# 8                  region_Northwest  2.144300
# 9                  region_Southeast  3.017075
# 10                 region_Southwest  2.739021
# 11         marital_status_Unmarried  2.450679
# 12             bmi_category_Obesity  1.479329
# 13          bmi_category_Overweight  1.737617
# 14         bmi_category_Underweight  1.258223
# 15        smoking_status_Occasional  1.379817
# 16           smoking_status_Regular  2.135497
# 17       employment_status_Salaried  3.218089
# 18  employment_status_Self-Employed  2.890329

# %% [markdown]
# ###### we will drop columns only if the vif is greater than 10 and columns are to be dropped one by one and then checked for vif however we are dropping vif to match lecture requirement
# | VIF Value  | Interpretation                                | Action Needed?               |
# | ---------- | --------------------------------------------- | ---------------------------- |
# | **1**      | No multicollinearity                          | ✅ Ideal                      |
# | **1 - 5**  | Moderate correlation                          | ✅ Usually okay               |
# | **5 - 10** | High correlation (possible multicollinearity) | ⚠️ Investigate further       |
# | **> 10**   | Severe multicollinearity                      | ❌ Remove or combine features |

# %%
calculate_vif(X.drop("income_level",axis=1))
# Out:
#                              column       Vif
# 0                        unnamed:_0  3.707947
# 1                               age  3.898275
# 2              number_of_dependants  6.573384
# 3                      income_lakhs  2.679612
# 4                    insurance_plan  4.576402
# 5             normalised_risk_score  3.845003
# 6                       gender_Male  2.593274
# 7                  region_Northwest  2.142869
# 8                  region_Southeast  3.015344
# 9                  region_Southwest  2.736554
# 10         marital_status_Unmarried  2.446174
# 11             bmi_category_Obesity  1.479250
# 12          bmi_category_Overweight  1.737576
# 13         bmi_category_Underweight  1.257850
# 14        smoking_status_Occasional  1.379733
# 15           smoking_status_Regular  2.134703
# 16       employment_status_Salaried  3.200636
# 17  employment_status_Self-Employed  2.883412

# %%
X_reduced=X.drop('income_level',axis=1)

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X_reduced,y,test_size=0.3,random_state=10)

# %%
print(f"X_train:{X_train.shape}")
print(f"X_test:{X_test.shape}")
print(f"y_train:{y_train.shape}")
print(f"y_test:{y_test.shape}")
# Out:
# X_train:(20875, 18)
# X_test:(8947, 18)
# y_train:(20875,)
# y_test:(8947,)

# %%
model_lr=LinearRegression()
model_lr.fit(X_train,y_train)
y_pred=model_lr.predict(X_test)


train_score=model_lr.score(X_train,y_train)
test_score=model_lr.score(X_test,y_test)
train_score,test_score
# Out:
# (0.9534184332289006, 0.9538411285760261)

# %%
model_lr.intercept_
# Out:
# 5918.711123550926

# %%
model_lr.coef_
# Out:
# array([ 6.88073831e-04,  7.01633082e+03, -1.31205589e+03, -7.08042262e+02,
#         1.48361753e+04,  6.05365807e+03,  3.76451740e+01, -5.53382927e+01,
#        -1.98130276e+01, -2.22809244e+01, -7.00512523e+02,  3.92707815e+03,
#         1.97924996e+03,  6.12987523e+02,  8.37571296e+02,  2.80060375e+03,
#        -4.53762326e+01,  2.43135608e+02])

# %%
X_test.columns
# Out:
# Index(['unnamed:_0', 'age', 'number_of_dependants', 'income_lakhs',
#        'insurance_plan', 'normalised_risk_score', 'gender_Male',
#        'region_Northwest', 'region_Southeast', 'region_Southwest',
#        'marital_status_Unmarried', 'bmi_category_Obesity',
#        'bmi_category_Overweight', 'bmi_category_Underweight',
#        'smoking_status_Occasional', 'smoking_status_Regular',
#        'employment_status_Salaried', 'employment_status_Self-Employed'],
#       dtype='object')

# %%
coef_df=pd.DataFrame(model_lr.coef_,X_test.columns,columns=["coefficient"]).reset_index()

coef_df=coef_df.sort_values(by='coefficient',ascending=False)
coef_df


plt.figure(figsize=(8,8))
sns.barplot(x=coef_df["coefficient"],y=coef_df["index"])
plt.show()

# %%
model_ridge=Ridge()

# %%
model_ridge=Ridge()
model_ridge.fit(X_train,y_train)
train_score=model_ridge.score(X_train,y_train)
test_score=model_ridge.score(X_test,y_test)
train_score,test_score
# Out:
# (0.9534182674866951, 0.9538420204822269)

# %%
from xgboost import XGBRegressor

# %%
from xgboost import XGBRegressor
model_xg=XGBRegressor()
model_xg.fit(X_train,y_train)
y_pred=model_xg.predict(X_test)
train_score=model_xg.score(X_train,y_train)
test_score=model_xg.score(X_test,y_test)
train_score,test_score
# Out:
# (0.998746395111084, 0.9979413747787476)

# %%
rsme=root_mean_squared_error(y_test,y_pred)

# %%
rsme
# Out:
# 312.0985427209399

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
print(np.sqrt(mse))
# Out:
# 97405.50036853437
# 312.0985427209399

# %%
model_xgb=XGBRegressor()
from sklearn.model_selection import RandomizedSearchCV
param_grid={
    'n_estimators':[20,40,50],
    'learning_rate':[0.01,0.1,0.2],
    'max_depth':[3,4,5]
}
random_search=RandomizedSearchCV(model_xgb,param_grid,n_iter=10,cv=3,scoring='r2')

# %%
random_search.fit(X_train,y_train)
random_search.best_score_
# Out:
# 0.9979577660560608

# %%
random_search.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 4, 'learning_rate': 0.2}

# %%
best_model=random_search.best_estimator_

# %%
best_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=50,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
best_model.feature_importances_
# Out:
# array([2.1016684e-05, 7.0936084e-02, 3.1628133e-05, 1.5284416e-04,
#        7.6387495e-01, 4.4098750e-02, 2.4504876e-05, 2.4848341e-05,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.1447859e-02,
#        2.5042351e-02, 3.2999194e-03, 6.5426454e-03, 4.4468932e-02,
#        0.0000000e+00, 3.3740584e-05], dtype=float32)

# %%
feature_importance=best_model.feature_importances_
coef_df=pd.DataFrame(feature_importance,index=X_test.columns,columns=["coefficient"]).reset_index()

coef_df=coef_df.sort_values(by='coefficient',ascending=False)
coef_df
# Out:
#                               index  coefficient
# 4                    insurance_plan     0.763875
# 1                               age     0.070936
# 15           smoking_status_Regular     0.044469
# 5             normalised_risk_score     0.044099
# 11             bmi_category_Obesity     0.041448
# 12          bmi_category_Overweight     0.025042
# 14        smoking_status_Occasional     0.006543
# 13         bmi_category_Underweight     0.003300
# 3                      income_lakhs     0.000153
# 17  employment_status_Self-Employed     0.000034
# 2              number_of_dependants     0.000032
# 7                  region_Northwest     0.000025
# 6                       gender_Male     0.000025
# 0                        unnamed:_0     0.000021
# 10         marital_status_Unmarried     0.000000
# 8                  region_Southeast     0.000000
# 16       employment_status_Salaried     0.000000
# 9                  region_Southwest     0.000000

# %%
plt.figure(figsize=(8,8))
plt.title("Feature importance in xgboost")
sns.barplot(x=coef_df["coefficient"],y=coef_df["index"])
plt.show()

# %% [markdown]
# # Error Analysis

# %%
res=pd.DataFrame({
    'y_test':y_test,
    'y_pred':y_pred,
    
})

# %%
res['residuals']=res['y_pred']-res['y_test']
res['residual%']=res['residuals']*100/res['y_test']
res.head()
# Out:
#        y_test        y_pred   residuals  residual%
# 19713   26895  26591.367188 -303.632812  -1.128956
# 14750   22734  23086.419922  352.419922   1.550189
# 19932   21198  21616.457031  418.457031   1.974040
# 29643    9100   8976.471680 -123.528320  -1.357454
# 17076   26434  26664.820312  230.820312   0.873195

# %%
sns.histplot(res['residual%'],kde=True)
# Out:
# <Axes: xlabel='residual%', ylabel='Count'>

# %%
extreme_error=10
extreme_error_threshold=res[np.abs(res['residual%'])>extreme_error]

# %%
len(extreme_error_threshold)*100/len(res)
# Out:
# 0.0

# %%
extreme_error=50
extreme_error_threshold=res[np.abs(res['residual%'])>extreme_error]

# %%
extreme_error_threshold.sort_values(by='residual%',ascending=False)
# Out:
# Empty DataFrame
# Columns: [y_test, y_pred, residuals, residual%]
# Index: []

# %%
extreme_error_threshold.index
# Out:
# Index([], dtype='int64')

# %%
extreme_error_df=X_test.loc[extreme_error_threshold.index]

# %%
for i in X_test.columns:
    plt.title(f"Error Analysis of {i} column")

    sns.histplot(X_test[i],label='overall',kde=True)
    sns.histplot(extreme_error_df[i],label='extreme error',kde=True)
    plt.legend()
    plt.show()

# %% [markdown]
# #### so we can find there is a error is higher in Age column

# %%
sns.histplot(extreme_error_df['age'])
# Out:
# <Axes: >

# %%
cols_to_scale
# Out:
# ['age',
#  'number_of_dependants',
#  'income_level',
#  'income_lakhs',
#  'insurance_plan']

# %%
extreme_error_df['income_level']=-1

# %%
extreme_error_df
# Out:
# Empty DataFrame
# Columns: [unnamed:_0, age, number_of_dependants, income_lakhs, insurance_plan, normalised_risk_score, gender_Male, region_Northwest, region_Southeast, region_Southwest, marital_status_Unmarried, bmi_category_Obesity, bmi_category_Overweight, bmi_category_Underweight, smoking_status_Occasional, smoking_status_Regular, employment_status_Salaried, employment_status_Self-Employed, income_level]
# Index: []

# %%
df_reversed=pd.DataFrame()
df_reversed[cols_to_scale]=scalar.inverse_transform(extreme_error_df[cols_to_scale])
df_reversed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 2
#       1 df_reversed=pd.DataFrame()
# ----> 2 df_reversed[cols_to_scale]=scalar.inverse_transform(extreme_error_df[cols_to_scale])
#       3 df_reversed
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:566, in MinMaxScaler.inverse_transform(self, X)
#     562 check_is_fitted(self)
#     564 xp, _ = get_namespace(X)
# --> 566 X = check_array(
#     567     X,
#     568     copy=self.copy,
#     569     dtype=_array_api.supported_float_dtypes(xp),
#     570     force_writeable=True,
#     571     force_all_finite="allow-nan",
#     572 )
#     574 X -= self.min_
#     575 X /= self.scale_
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1085     n_samples = _num_samples(array)
#    1086     if n_samples < ensure_min_samples:
# -> 1087         raise ValueError(
#    1088             "Found array with %d sample(s) (shape=%s) while a"
#    1089             " minimum of %d is required%s."
#    1090             % (n_samples, array.shape, ensure_min_samples, context)
#    1091         )
#    1093 if ensure_min_features > 0 and array.ndim == 2:
#    1094     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 5)) while a minimum of 1 is required.

# %%
df_reversed.age.quantile(0.97)

# %% [markdown]
# # model Segmentation

# %%
import os
print(os.getcwd())
